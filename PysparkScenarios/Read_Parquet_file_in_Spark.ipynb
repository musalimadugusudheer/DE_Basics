# %%
df = spark.read.parquet("/Volumes/pyspark_cata/source/db_volume/part-r-00000-1a9822ba-b8fb-4d8e-844a-ea30d0801b9e.gz.parquet")
df.show()

# %%
df = spark.read.format("csv")\
            .option("header", "true")\
            .option("inferSchema", "true")\
            .load("/Volumes/pyspark_cata/source/db_volume/employee_write_Data.csv")

df.show()

# %%
df.write.format("csv")\
        .option("header", "true")\
        .option("mode", "overwrite")\
        .option("path","/Volumes/pyspark_cata/source/db_volume/csv_write/")\
        .save()

# %%
dbutils.fs.ls("/Volumes/pyspark_cata/source/db_volume/csv_write/")

# %%
df.repartition(3).write.format("csv")\
                        .option("header", "true")\
                        .mode("overwrite")\
                        .option("path","/Volumes/pyspark_cata/source/db_volume/csv_write_repartition/")\
                        .save()

# %%
dbutils.fs.ls("/Volumes/pyspark_cata/source/db_volume/csv_write_repartition/")

# %%
df.write.format("csv")\
        .option("header", "true")\
        .option("mode","overwrite")\
        .option("path","/Volumes/pyspark_cata/source/db_volume/partition_by_address/")\
        .partitionBy("address")\
        .save()

# %%
dbutils.fs.ls("/Volumes/pyspark_cata/source/db_volume/partition_by_address/")

# %%
df.write.format("csv")\
        .option("header", "true")\
        .option("mode","overwrite")\
        .option("path","/Volumes/pyspark_cata/source/db_volume/partition_by_id/")\
        .partitionBy("id")\
        .save()

# %%
dbutils.fs.ls("/Volumes/pyspark_cata/source/db_volume/partition_by_id/")

# %%
df.write.format("csv")\
        .option("header", "true")\
        .option("mode","overwrite")\
        .option("path","/Volumes/pyspark_cata/source/db_volume/partition_by_address_gender/")\
        .partitionBy("address","gender")\
        .save()

# %%
dbutils.fs.ls("/Volumes/pyspark_cata/source/db_volume/partition_by_address_gender/")

# %%
dbutils.fs.ls("dbfs:/Volumes/pyspark_cata/source/db_volume/partition_by_address_gender/address=INDIA/")

# %%
df.write.format("csv")\
        .option("header", "true")\
        .option("mode","overwrite")\
        .option("path","/Volumes/pyspark_cata/source/db_volume/partition_by_gender_address/")\
        .partitionBy("gender","address")\
        .save()

# %%
dbutils.fs.ls("/Volumes/pyspark_cata/source/db_volume/partition_by_gender_address/")

# %%
dbutils.fs.ls("/Volumes/pyspark_cata/source/db_volume/partition_by_gender_address/gender=m/")

# %%
df.write.format("delta") \
    .mode("overwrite") \
    .saveAsTable("bucket_by_id_table")

# %%
display(
    spark.sql(
        "DESCRIBE FORMATTED bucket_by_id_table"
    )
)

# %%
df = spark.read.format("csv")\
            .option("header", "true")\
            .option("inferSchema", "true")\
            .load("/Volumes/pyspark_cata/source/db_volume/employee_write_Data.csv")

df.show()

# %%
df.write.format("csv")\
        .option("header", "true")\
        .option("mode","overwrite")\
        .option("path","/Volumes/pyspark_cata/source/db_volume/bucket_by_id/")\
        .bucketBy(3,"id")\
        .saveAsTable("bucket_by_id_table")
