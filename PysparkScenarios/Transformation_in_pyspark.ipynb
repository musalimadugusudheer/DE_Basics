# %%
##### Imports ######
from pyspark.sql.functions import *
from pyspark.sql.types import *

##### Reading Data ######
employee_df=spark.read.format("csv")\
        .option("header", "true")\
        .option("inferSchema", "true")\
        .option("mode", "PERMISSIVE")\
        .load("/Volumes/pyspark_cata/source/db_volume/employee_file.csv")

employee_df.show()

##### Printing Schema ######
employee_df.printSchema()

##### Creating Temporary View ######
emp_employee_df.createOrReplaceTempView("employee_tbl")

# %%
employee_df.select(col("id").alias("employee_id"), "name","salary").show()

# %%
employee_df.filter(col("salary")>150000).show()

# %%
employee_df.where(col("salary")>150000).show()

# %%
employee_df.filter((col("salary")>150000) & (col("age")<18)).show()

# %%
employee_df.select("*", lit("kumar").alias("last_name")).show()

# %%
employee_df.withColumn("sur_name", lit("simgh")).show()

# %%
employee_df.withColumnRenamed("id","employee_id").show()

# %%
new_employee_df = employee_df.withColumnRenamed("id","employee_id")

# %%
  new_employee_df.show()

# %%
employee_df.printSchema()

# %%
employee_df.withColumn("id",col("id").cast("string"))\
            .withColumn("salary",col("salary").cast("long"))\
        .printSchema()

# %%
employee_df.drop("id",col("name")).show()

# %%
data=[(10 ,'Anil',50000, 18),
(11 ,'Vikas',75000,  16),
(12 ,'Nisha',40000,  18),
(13 ,'Nidhi',60000,  17),
(14 ,'Priya',80000,  18),
(15 ,'Mohit',45000,  18),
(16 ,'Rajesh',90000, 10),
(17 ,'Raman',55000, 16),
(18 ,'Sam',65000,   17),
(15 ,'Mohit',45000,  18),
(13 ,'Nidhi',60000,  17),      
(14 ,'Priya',90000,  18),  
(18 ,'Sam',65000,   17)
     ]

schema = ['id','name','salary','mgr_id']
manager_df = spark.createDataFrame(data=data,schema=schema)
manager_df.show()

# %%
manager_df.distinct().show()

# %%
manager_df.distinct().count()

# %%
manager_df.count()

# %%
manager_df.distinct("id","name").show()

# %%
manager_df.select ("id","name").distinct().show()

# %%
dropped_mgr_data = manager_df.dropDuplicates(["id","name","salary","mgr_id"])

# %%
dropped_mgr_data.show()

# %%
from pyspark.sql.functions import *

# %%
manager_df.sort(col("salary")).show()

# %%
manager_df.sort(col("salary").desc(),col("name").desc()).show()
