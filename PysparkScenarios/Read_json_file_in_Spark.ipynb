# %%
spark.read.format("json")\
        .option("inferSchema", "true")\
        .option("mode", "permissive")\
        .load("/Volumes/pyspark_cata/source/db_volume/line_delimited_json.json").show()

# %%
spark.read.format("json")\
        .option("inferSchema", "true")\
        .option("mode", "permissive")\
        .load("/Volumes/pyspark_cata/source/db_volume/line_delimited_json_extrafield.json").show()

# %%
spark.read.format("json")\
        .option("inferSchema", "true")\
        .option("mode", "permissive")\
        .option("multiLine", "true")\
        .load("/Volumes/pyspark_cata/source/db_volume/Multi_line_correct.json").show()

# %%
spark.read.format("json")\
        .option("inferSchema", "true")\
        .option("mode", "permissive")\
        .option("multiLine", "true")\
        .load("/Volumes/pyspark_cata/source/db_volume/Multi_line_incorrect.json").show()

# %%
spark.read.format("json")\
        .option("inferSchema", "true")\
        .option("mode", "permissive")\
        .load("/Volumes/pyspark_cata/source/db_volume/corrupted_json.json").show(truncate=False)

# %%
spark.read.format("json")\
        .option("inferSchema", "true")\
        .option("mode", "permissive")\
        .load("/Volumes/pyspark_cata/source/db_volume/file5.json").printSchema()
