# %%
spark.version

# %%
flight_df = spark.read.format("csv")\
  .option("header", "false")\
  .option("inferSchema", "false")\
  .option("mode", "FAILFAST")\
  .load("/Volumes/pyspark_cata/source/db_volume/flight_Data.csv")

flight_df.show(5)

# %%
flight_df_header = spark.read.format("csv")\
  .option("header", "true")\
  .option("inferSchema", "false")\
  .option("mode", "FAILFAST")\
  .load("/Volumes/pyspark_cata/source/db_volume/flight_Data.csv")

flight_df_header.show(5)

# %%
flight_df_header.printSchema()

# %%
flight_df_header_schema = spark.read.format("csv")\
  .option("header", "true")\
  .option("inferSchema", "true")\
  .option("mode", "FAILFAST")\
  .load("/Volumes/pyspark_cata/source/db_volume/flight_Data.csv")

flight_df_header_schema.show(5)

# %%
flight_df_header_schema.printSchema()

# %%
flight_df = spark.read.format("csv")\
  .option("header", "false")\
  .option("inferSchema", "false")\
  .schema(my_schema)\
  .option("mode", "FAILFAST")\
  .load("/Volumes/pyspark_cata/source/db_volume/flight_Data.csv")

flight_df.show(5)

# %%
from pyspark.sql.types import StructField,StructType,StringType,IntegerType

# %%
my_schema = StructType([
  StructField("DEST_COUNTRY_NAME", StringType(), True),
  StructField("ORIGIN_COUNTRY_NAME", StringType(), True),
  StructField("count", IntegerType(), False)
])

# %%
flight_df = spark.read.format("csv")\
  .option("header", "false")\
  .option("skipRows", 1)\
  .option("inferSchema", "false")\
  .schema(my_schema)\
  .option("mode", "PERMISSIVE")\
  .load("/Volumes/pyspark_cata/source/db_volume/flight_Data.csv")

flight_df.show(5)

# %%
# %fs
ls /Volumes/pyspark_cata/source/db_volume/

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
employee_df=spark.read.format("csv")\
        .option("header", "true")\
        .option("inferSchema", "true")\
        .option("mode", "PERMISSIVE")\
        .load("/Volumes/pyspark_cata/source/db_volume/employee_file.csv")

employee_df.show()

# %%
employee_df.columns

# %%
employee_df.printSchema()

# %%
emp_schema = StructType ([
  StructField("id", IntegerType(), True),
  StructField("name", StringType(), True),
  StructField("age", IntegerType(), True),
  StructField("salary", IntegerType(), True),
  StructField("address", StringType(), True),
  StructField("nominee", StringType(), True),
  StructField("_corrupt_record", StringType(), True)
])

# %%
employee_df.printSchema()

# %%
employee_df.select("name").show()

# %%
employee_df.select(col("name")).show()

# %%
employee_df.select(col("id") +5 ).show()

# %%
employee_df.select("id","name","age","salary").show()

# %%
employee_df.select(col("id"),col("name"),col("age"),col("salary")).show()

# %%
employee_df.select("id",col("name"),employee_df["salary"],employee_df.address).show()

# %% [markdown]
# ## Expression

# %%
employee_df.select(expr("id +5")).show()

# %%
employee_df.select(expr("id as employee_id"),
                   expr("name as employee_name"),
                   expr("concat(name, address)")).show()

# %% [markdown]
# ## Spark SQL

# %%
employee_df.createOrReplaceTempView("employee_tbl")

# %%
spark.sql("""
          select * from employee_tbl
          """).show()

# %%
##### Imports ######
from pyspark.sql.functions import *
from pyspark.sql.types import *

##### Reading Data ######
employee_df=spark.read.format("csv")\
        .option("header", "true")\
        .option("inferSchema", "true")\
        .option("mode", "PERMISSIVE")\
        .load("/Volumes/pyspark_cata/source/db_volume/employee_file.csv")

employee_df.show()

##### Printing Schema ######
employee_df.printSchema()

##### Creating Temporary View ######
employee_df.createOrReplaceTempView("employee_tbl")

# %%
employee_df=spark.read.format("csv")\
        .option("header", "true")\
        .option("inferSchema", "true")\
        .option("mode", "dropMalformed")\
        .load("/Volumes/pyspark_cata/source/db_volume/employee_file.csv")



employee_df.show()

# %%
employee_df=spark.read.format("csv")\
        .option("header", "true")\
        .option("inferSchema", "true")\
        .option("mode", "FAILFAST")\
        .load("/Volumes/pyspark_cata/source/db_volume/employee_file.csv")

display(employee_df)

# %%
from pyspark.sql.types import StructField,StructType,StringType,IntegerType

# %%
emp_schema = StructType ([
  StructField("id", IntegerType(), True),
  StructField("name", StringType(), True),
  StructField("age", IntegerType(), True),
  StructField("salary", IntegerType(), True),
  StructField("address", StringType(), True),
  StructField("nominee", StringType(), True),
  StructField("_corrupt_record", StringType(), True)
])

# %%
employee_df=spark.read.format("csv")\
        .option("header", "true")\
        .option("inferSchema", "true")\
        .option("mode", "PERMISSIVE")\
        .schema(emp_schema)\
        .load("/Volumes/pyspark_cata/source/db_volume/employee_file.csv")

employee_df.show(truncate=False)

# %%
employee_df=spark.read.format("csv")\
        .option("header", "true")\
        .option("inferSchema", "true")\
        .schema(emp_schema)\
        .option("badRecordsPath", "/Volumes/pyspark_cata/source/db_volume/bad_records")\
        .load("/Volumes/pyspark_cata/source/db_volume/employee_file.csv")

employee_df.show(truncate=False)

# %%
# %fs
ls /Volumes/pyspark_cata/source/db_volume/bad_records/20251016T165408/bad_records/part-00000-ec4cdc08-653a-4a19-a544-779a2be2bc81

# %%
bad_data_df=  spark.read.format("json").load("dbfs:/Volumes/pyspark_cata/source/db_volume/bad_records/20251016T165408/bad_records/")

bad_data_df.show(truncate=False)
